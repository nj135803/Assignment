# %% [markdown]
# # Pandas Assignmenet 3(B)

# %% [markdown]
# # Introduction:
# The data have been modified to contain some missing values, identified by NaN.
# Using pandas should make this exercise easier, in particular for the bonus question.
#
# You should be able to perform all of these operations without using a for loop or other looping construct.
#
# 1. The data in 'wind.data' has the following format:

# %%
"""
Yr Mo Dy   RPT   VAL   ROS   KIL   SHA   BIR   DUB   CLA   MUL   CLO   BEL   MAL
61  1  1 15.04 14.96 13.17  9.29   NaN  9.87 13.67 10.25 10.83 12.58 18.50 15.04
61  1  2 14.71   NaN 10.83  6.50 12.62  7.67 11.50 10.04  9.79  9.67 17.54 13.83
61  1  3 18.50 16.88 12.33 10.13 11.17  6.17 11.25   NaN  8.50  7.67 12.75 12.71
"""
# Out:
# '\nYr Mo Dy   RPT   VAL   ROS   KIL   SHA   BIR   DUB   CLA   MUL   CLO   BEL   MAL\n61  1  1 15.04 14.96 13.17  9.29   NaN  9.87 13.67 10.25 10.83 12.58 18.50 15.04\n61  1  2 14.71   NaN 10.83  6.50 12.62  7.67 11.50 10.04  9.79  9.67 17.54 13.83\n61  1  3 18.50 16.88 12.33 10.13 11.17  6.17 11.25   NaN  8.50  7.67 12.75 12.71\n'

# %% [markdown]
# Each line corresponds to one day of data in the following format: year, month, day, average wind speed at each of the stations in the order given
#
# RPT, VAL, ROS, KIL, SHA, BIR, DUB, CLA, MUL, CLO, BEL, MAL

# %% [markdown]
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd
import datetime

# %% [markdown]
# ### Step 2. Import the dataset from this address

# %%
data = pd.read_csv('Data (2).csv', sep = "\s+")

# %%
data.head()
# Out:
#    Yr  Mo  Dy    RPT    VAL    ROS    KIL    SHA   BIR    DUB    CLA    MUL  \
# 0  61   1   1  15.04  14.96  13.17   9.29    NaN  9.87  13.67  10.25  10.83
# 1  61   1   2  14.71    NaN  10.83   6.50  12.62  7.67  11.50  10.04   9.79
# 2  61   1   3  18.50  16.88  12.33  10.13  11.17  6.17  11.25    NaN   8.50
# 3  61   1   4  10.58   6.63  11.75   4.58   4.54  2.88   8.63   1.79   5.83
# 4  61   1   5  13.33  13.25  11.42   6.17  10.71  8.21  11.92   6.54  10.92
#
#      CLO    BEL    MAL
# 0  12.58  18.50  15.04
# 1   9.67  17.54  13.83
# 2   7.67  12.75  12.71
# 3   5.88   5.46  10.88
# 4  10.34  12.92  11.83

# %% [markdown]
# ### Step 3. Assign it to a variable called data and replace the first 3 columns by a proper datetime index.

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6574 entries, 0 to 6573
# Data columns (total 15 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Yr      6574 non-null   int64
#  1   Mo      6574 non-null   int64
#  2   Dy      6574 non-null   int64
#  3   RPT     6568 non-null   float64
#  4   VAL     6571 non-null   float64
#  5   ROS     6572 non-null   float64
#  6   KIL     6569 non-null   float64
#  7   SHA     6572 non-null   float64
#  8   BIR     6574 non-null   float64
#  9   DUB     6571 non-null   float64
#  10  CLA     6572 non-null   float64
#  11  MUL     6571 non-null   float64
#  12  CLO     6573 non-null   float64
#  13  BEL     6574 non-null   float64
#  14  MAL     6570 non-null   float64
# dtypes: float64(12), int64(3)
# memory usage: 770.5 KB

# %%
data1 = data

# %%
data['date_string'] = data.Yr.astype(str) + "-"  + data.Mo.astype(str) + "-" + data.Dy.astype(str)

# %%
data['date_string']
# Out:
# 0         61-1-1
# 1         61-1-2
# 2         61-1-3
# 3         61-1-4
# 4         61-1-5
#           ...
# 6569    78-12-27
# 6570    78-12-28
# 6571    78-12-29
# 6572    78-12-30
# 6573    78-12-31
# Name: date_string, Length: 6574, dtype: object

# %%
data['date'] = pd.to_datetime(data['date_string'], format='%y-%m-%d')

# %%
data.head()
# Out:
#    Yr  Mo  Dy    RPT    VAL    ROS    KIL    SHA   BIR    DUB    CLA    MUL  \
# 0  61   1   1  15.04  14.96  13.17   9.29    NaN  9.87  13.67  10.25  10.83
# 1  61   1   2  14.71    NaN  10.83   6.50  12.62  7.67  11.50  10.04   9.79
# 2  61   1   3  18.50  16.88  12.33  10.13  11.17  6.17  11.25    NaN   8.50
# 3  61   1   4  10.58   6.63  11.75   4.58   4.54  2.88   8.63   1.79   5.83
# 4  61   1   5  13.33  13.25  11.42   6.17  10.71  8.21  11.92   6.54  10.92
#
#      CLO    BEL    MAL date_string       date
# 0  12.58  18.50  15.04      61-1-1 2061-01-01
# 1   9.67  17.54  13.83      61-1-2 2061-01-02
# 2   7.67  12.75  12.71      61-1-3 2061-01-03
# 3   5.88   5.46  10.88      61-1-4 2061-01-04
# 4  10.34  12.92  11.83      61-1-5 2061-01-05

# %%
data.tail()
# Out:
#       Yr  Mo  Dy    RPT    VAL    ROS   KIL    SHA    BIR    DUB    CLA  \
# 6569  78  12  27  17.58  16.96  17.62  8.08  13.21  11.67  14.46  15.59
# 6570  78  12  28  13.21   5.46  13.46  5.00   8.12   9.42  14.33  16.25
# 6571  78  12  29  14.00  10.29  14.42  8.71   9.71  10.54  19.17  12.46
# 6572  78  12  30  18.50  14.04  21.29  9.13  12.75   9.71  18.08  12.87
# 6573  78  12  31  20.33  17.41  27.29  9.59  12.08  10.13  19.25  11.63
#
#         MUL    CLO    BEL    MAL date_string       date
# 6569  14.04  14.00  17.21  40.08    78-12-27 1978-12-27
# 6570  15.25  18.05  21.79  41.46    78-12-28 1978-12-28
# 6571  14.50  16.42  18.88  29.58    78-12-29 1978-12-29
# 6572  12.46  12.12  14.67  28.79    78-12-30 1978-12-30
# 6573  11.58  11.38  12.08  22.08    78-12-31 1978-12-31

# %% [markdown]
# ### Step 4. Year 2061? Do we really have data from this year? Create a function to fix it and apply it.

# %%
def fix_century(x):
  year = x.year - 100 if x.year > 1989 else x.year
  return datetime.date(year, x.month, x.day)

data['date'] = data['date'].apply(fix_century)
data.head()
# Out:
#    Yr  Mo  Dy    RPT    VAL    ROS    KIL    SHA   BIR    DUB    CLA    MUL  \
# 0  61   1   1  15.04  14.96  13.17   9.29    NaN  9.87  13.67  10.25  10.83
# 1  61   1   2  14.71    NaN  10.83   6.50  12.62  7.67  11.50  10.04   9.79
# 2  61   1   3  18.50  16.88  12.33  10.13  11.17  6.17  11.25    NaN   8.50
# 3  61   1   4  10.58   6.63  11.75   4.58   4.54  2.88   8.63   1.79   5.83
# 4  61   1   5  13.33  13.25  11.42   6.17  10.71  8.21  11.92   6.54  10.92
#
#      CLO    BEL    MAL date_string        date
# 0  12.58  18.50  15.04      61-1-1  1961-01-01
# 1   9.67  17.54  13.83      61-1-2  1961-01-02
# 2   7.67  12.75  12.71      61-1-3  1961-01-03
# 3   5.88   5.46  10.88      61-1-4  1961-01-04
# 4  10.34  12.92  11.83      61-1-5  1961-01-05

# %% [markdown]
# ### Step 5. Set the right dates as the index. Pay attention at the data type, it should be datetime64[ns].

# %%
data["date"] = pd.to_datetime(data["date"])
data = data.set_index('date')
data.head()
# Out:
#             Yr  Mo  Dy    RPT    VAL    ROS    KIL    SHA   BIR    DUB    CLA  \
# date
# 1961-01-01  61   1   1  15.04  14.96  13.17   9.29    NaN  9.87  13.67  10.25
# 1961-01-02  61   1   2  14.71    NaN  10.83   6.50  12.62  7.67  11.50  10.04
# 1961-01-03  61   1   3  18.50  16.88  12.33  10.13  11.17  6.17  11.25    NaN
# 1961-01-04  61   1   4  10.58   6.63  11.75   4.58   4.54  2.88   8.63   1.79
# 1961-01-05  61   1   5  13.33  13.25  11.42   6.17  10.71  8.21  11.92   6.54
#
#               MUL    CLO    BEL    MAL date_string
# date
# 1961-01-01  10.83  12.58  18.50  15.04      61-1-1
# 1961-01-02   9.79   9.67  17.54  13.83      61-1-2
# 1961-01-03   8.50   7.67  12.75  12.71      61-1-3
# 1961-01-04   5.83   5.88   5.46  10.88      61-1-4
# 1961-01-05  10.92  10.34  12.92  11.83      61-1-5

# %% [markdown]
# ### Step 6. Compute how many values are missing for each location over the entire record.
# #### They should be ignored in all calculations below.

# %%
data.isna().sum()
# Out:
# Yr             0
# Mo             0
# Dy             0
# RPT            6
# VAL            3
# ROS            2
# KIL            5
# SHA            2
# BIR            0
# DUB            3
# CLA            2
# MUL            3
# CLO            1
# BEL            0
# MAL            4
# date_string    0
# dtype: int64

# %% [markdown]
# ### Step 7. Compute how many non-missing values there are in total.

# %%
data.shape[0] - data.isnull().sum()
# Out:
# Yr             6574
# Mo             6574
# Dy             6574
# RPT            6568
# VAL            6571
# ROS            6572
# KIL            6569
# SHA            6572
# BIR            6574
# DUB            6571
# CLA            6572
# MUL            6571
# CLO            6573
# BEL            6574
# MAL            6570
# date_string    6574
# dtype: int64

# %% [markdown]
# ### Step 8. Calculate the mean windspeeds of the windspeeds over all the locations and all the times.
# #### A single number for the entire dataset.

# %%
rd = data.loc[:, "RPT" : "MAL"]

# %%
rd.mean(0).mean()
# Out:
# 10.227982360836938

# %%
rd.mean().mean(0)
# Out:
# 10.227982360836938

# %% [markdown]
# ### Step 9. Create a DataFrame called loc_stats and calculate the min, max and mean windspeeds and standard deviations of the windspeeds at each location over all the days
#
# #### A different set of numbers for each location.

# %%
rd.describe()
# Out:
#                RPT          VAL          ROS          KIL          SHA  \
# count  6568.000000  6571.000000  6572.000000  6569.000000  6572.000000
# mean     12.362987    10.644314    11.660526     6.306468    10.455834
# std       5.618413     5.267356     5.008450     3.605811     4.936125
# min       0.670000     0.210000     1.500000     0.000000     0.130000
# 25%       8.120000     6.670000     8.000000     3.580000     6.750000
# 50%      11.710000    10.170000    10.920000     5.750000     9.960000
# 75%      15.920000    14.040000    14.670000     8.420000    13.540000
# max      35.800000    33.370000    33.840000    28.460000    37.540000
#
#                BIR          DUB          CLA          MUL          CLO  \
# count  6574.000000  6571.000000  6572.000000  6571.000000  6573.000000
# mean      7.092254     9.797343     8.495053     8.493590     8.707332
# std       3.968683     4.977555     4.499449     4.166872     4.503954
# ...

# %% [markdown]
# ### Step 10. Create a DataFrame called day_stats and calculate the min, max and mean windspeed and standard deviations of the windspeeds across all the locations at each day.
#
# #### A different set of numbers for each day.

# %%
rd.head().T.describe()
# Out:
# date   1961-01-01  1961-01-02  1961-01-03  1961-01-04  1961-01-05
# count   11.000000   11.000000   11.000000   12.000000   12.000000
# mean    13.018182   11.336364   11.641818    6.619167   10.630000
# std      2.808875    3.188994    3.681912    3.198126    2.445356
# min      9.290000    6.500000    6.170000    1.790000    6.170000
# 25%     10.540000    9.730000    9.315000    4.570000    9.807500
# 50%     13.170000   10.830000   11.250000    5.855000   11.170000
# 75%     15.000000   13.225000   12.730000    9.117500   12.170000
# max     18.500000   17.540000   18.500000   11.750000   13.330000

# %% [markdown]
# ### Step 11. Find the average windspeed in January for each location.
# #### Treat January 1961 and January 1962 both as January.

# %%
data[data.Mo == 1].loc[:, 'RPT' : 'MAL'].mean()
# Out:
# RPT    14.847325
# VAL    12.914560
# ROS    13.299624
# KIL     7.199498
# SHA    11.667734
# BIR     8.054839
# DUB    11.819355
# CLA     9.512047
# MUL     9.543208
# CLO    10.053566
# BEL    14.550520
# MAL    18.028763
# dtype: float64

# %% [markdown]
# ### Step 12. Downsample the record to a yearly frequency for each location.

# %%
data.groupby(data.index.to_period('A')).sum()
# Out:
#          Yr    Mo    Dy      RPT      VAL      ROS      KIL      SHA      BIR  \
# date
# 1961  22265  2382  5738  4427.85  3747.35  4124.54  2511.92  3950.08  2821.35
# 1962  22630  2382  5738  4457.88  3690.31  4282.44  2533.60  3890.14  2698.47
# 1963  22995  2382  5738  4676.91  3955.50  4577.52  2675.47  4279.30  3078.67
# 1964  23424  2384  5767  4525.10  3996.78  4430.20  2484.33  4192.34  2770.94
# 1965  23725  2382  5738  4544.75  4042.57  4324.80  2503.34  4024.05  2729.51
# 1966  24090  2382  5738  4913.62  4218.38  4387.53  2681.19  4308.84  2844.69
# 1967  24455  2382  5738  4649.06  4011.71  4284.88  2607.35  4245.22  2689.38
# 1968  24888  2384  5767  4331.84  3831.36  4175.97  2370.83  3938.44  2220.64
# 1969  25185  2382  5738  4075.72  3549.15  3979.23  2105.31  3603.98  2259.34
# 1970  25550  2382  5738  4599.12  3915.33  4281.54  2269.27  3857.09  2777.45
# 1971  25915  2382  5738  4114.69  3319.74  4047.24  1913.15  3445.72  2225.46
# ...

# %% [markdown]
# ### Step 13. Downsample the record to a monthly frequency for each location.

# %%
data.groupby(data.index.to_period('M')).sum()
# Out:
#            Yr   Mo   Dy     RPT     VAL     ROS     KIL     SHA     BIR  \
# date
# 1961-01  1891   31  496  445.24  359.65  416.38  239.84  321.11  266.23
# 1961-02  1708   56  406  455.54  419.31  389.92  249.23  387.86  306.25
# 1961-03  1891   93  496  326.70  350.19  333.34  218.52  325.79  274.87
# 1961-04  1830  120  465  321.68  282.83  299.94  174.92  253.05  194.85
# 1961-05  1891  155  496  305.69  265.50  335.36  177.16  294.20  203.82
# ...       ...  ...  ...     ...     ...     ...     ...     ...     ...
# 1978-08  2418  248  496  299.00  256.04  280.00  139.59  228.41  183.99
# 1978-09  2340  270  465  327.41  326.85  319.05  171.75  311.16  278.35
# 1978-10  2418  310  496  306.83  268.80  288.17  146.36  264.28  210.00
# 1978-11  2340  330  465  484.55  444.08  405.24  219.52  344.25  262.29
# 1978-12  2418  372  496  501.44  426.19  484.69  219.94  353.36  286.49
#
#             DUB     CLA     MUL     CLO     BEL     MAL  \
# date
# ...

# %% [markdown]
# ### Step 14. Downsample the record to a weekly frequency for each location.

# %%
data.groupby(data.index.to_period('W')).sum()
# Out:
#                         Yr  Mo   Dy     RPT     VAL     ROS    KIL     SHA  \
# date
# 1960-12-26/1961-01-01   61   1    1   15.04   14.96   13.17   9.29    0.00
# 1961-01-02/1961-01-08  427   7   35   94.79   68.92   73.41  44.92   66.32
# 1961-01-09/1961-01-15  427   7   84   87.28   62.77   83.71  32.41   51.46
# 1961-01-16/1961-01-22  427   7  133   92.43   69.04   90.88  44.30   53.80
# 1961-01-23/1961-01-29  427   7  182  119.28  112.99  127.58  89.04  122.03
# ...                    ...  ..  ...     ...     ...     ...    ...     ...
# 1978-11-27/1978-12-03  546  80  120  104.54   78.63   97.59  38.96   71.51
# 1978-12-04/1978-12-10  546  84   49  145.18  134.33  119.24  68.44  107.01
# 1978-12-11/1978-12-17  546  84   98  117.31  102.85  104.91  48.42   79.78
# 1978-12-18/1978-12-24  546  84  147   78.09   56.06   92.21  28.03   54.78
# 1978-12-25/1978-12-31  546  84  196  104.66   82.61  112.25  45.55   67.62
#
# ...

# %% [markdown]
# ### Step 15. Calculate the min, max and mean windspeeds and standard deviations of the windspeeds across all locations for each week (assume that the first week starts on January 2 1961) for the first 52 weeks.

# %%
print(data.head())
# Out:
#             Yr  Mo  Dy    RPT    VAL    ROS    KIL    SHA   BIR    DUB    CLA  \
# date
# 1961-01-01  61   1   1  15.04  14.96  13.17   9.29    NaN  9.87  13.67  10.25
# 1961-01-02  61   1   2  14.71    NaN  10.83   6.50  12.62  7.67  11.50  10.04
# 1961-01-03  61   1   3  18.50  16.88  12.33  10.13  11.17  6.17  11.25    NaN
# 1961-01-04  61   1   4  10.58   6.63  11.75   4.58   4.54  2.88   8.63   1.79
# 1961-01-05  61   1   5  13.33  13.25  11.42   6.17  10.71  8.21  11.92   6.54
#
#               MUL    CLO    BEL    MAL date_string
# date
# 1961-01-01  10.83  12.58  18.50  15.04  2061-01-01
# 1961-01-02   9.79   9.67  17.54  13.83  2061-01-02
# 1961-01-03   8.50   7.67  12.75  12.71  2061-01-03
# 1961-01-04   5.83   5.88   5.46  10.88  2061-01-04
# 1961-01-05  10.92  10.34  12.92  11.83  2061-01-05

# %%
print(data.columns)
# Out:
# Index(['Yr', 'Mo', 'Dy', 'RPT', 'VAL', 'ROS', 'KIL', 'SHA', 'BIR', 'DUB',
#        'CLA', 'MUL', 'CLO', 'BEL', 'MAL', 'date_string'],
#       dtype='object')

# %%
for column in data.columns:
    print(f"Column: {column}")
    print(data[column].head())
    print("\n")
# Out:
# Column: Yr
# date
# 1961-01-01    61
# 1961-01-02    61
# 1961-01-03    61
# 1961-01-04    61
# 1961-01-05    61
# Name: Yr, dtype: int64
#
#
# Column: Mo
# date
# 1961-01-01    1
# 1961-01-02    1
# 1961-01-03    1
# 1961-01-04    1
# 1961-01-05    1
# Name: Mo, dtype: int64
#
#
# Column: Dy
# date
# 1961-01-01    1
# 1961-01-02    2
# 1961-01-03    3
# 1961-01-04    4
# 1961-01-05    5
# Name: Dy, dtype: int64
#
#
# Column: RPT
# date
# 1961-01-01    15.04
# 1961-01-02    14.71
# 1961-01-03    18.50
# 1961-01-04    10.58
# 1961-01-05    13.33
# Name: RPT, dtype: float64
#
#
# Column: VAL
# date
# 1961-01-01    14.96
# 1961-01-02      NaN
# 1961-01-03    16.88
# 1961-01-04     6.63
# 1961-01-05    13.25
# Name: VAL, dtype: float64
#
#
# Column: ROS
# date
# 1961-01-01    13.17
# 1961-01-02    10.83
# 1961-01-03    12.33
# 1961-01-04    11.75
# 1961-01-05    11.42
# Name: ROS, dtype: float64
#
#
# Column: KIL
# date
# 1961-01-01     9.29
# 1961-01-02     6.50
# 1961-01-03    10.13
# ...

# %%
print("Non-null count in 'RPT':", data['RPT'].notnull().sum())
print("Unique values in 'RPT':", data['RPT'].unique())
# Out:
# Non-null count in 'RPT': 6568
# Unique values in 'RPT': [15.04 14.71 18.5  10.58 13.33 13.21 13.5  10.96 12.58 13.37 19.75  9.92
#   9.04 12.04 16.42 17.75 19.83  4.92  9.59 14.33 16.54 25.04 13.62 24.37
#  22.04 17.67   nan 12.21 24.21 14.25 20.17 14.37 22.   24.5  18.05 24.54
#  17.41 20.5  16.79 16.   22.5  17.08  6.04 15.25 12.08 16.17 11.04  7.79
#  12.29 22.08  8.71 18.84 25.8  11.   12.92 12.67 11.25  4.88  6.46  7.54
#  11.96 10.63 14.79 11.21 12.12 11.12 15.71 16.88 11.42 13.75  9.54  6.34
#   6.38  6.29  9.67 15.    5.88  8.46 18.25  8.96  8.38  7.62 15.29 13.92
#  18.12  4.5   8.21 10.34  5.75 10.5  15.5   5.17  4.71  4.   10.83 16.71
#  21.09 15.34  8.17 14.04 16.29  4.08  5.58  9.62 11.67 15.87 19.04  9.87
#  23.   18.16 12.79  4.79  3.54  7.    9.25 10.    5.    6.21  6.83  6.25
#   4.96  5.54  7.67 11.79 10.92  9.96 15.92 11.29  7.5   8.5  11.58  8.33
#  11.92 12.17  9.71 14.42  8.29  6.13 13.88  8.92  8.54  8.83  5.71  6.42
# ...

# %%
non_null_counts = data[['RPT', 'VAL', 'ROS', 'KIL', 'SHA', 'BIR', 'DUB', 'CLA', 'MUL', 'CLO', 'BEL', 'MAL']].notnull().sum()
print(non_null_counts)
# Out:
# RPT    6568
# VAL    6571
# ROS    6572
# KIL    6569
# SHA    6572
# BIR    6574
# DUB    6571
# CLA    6572
# MUL    6571
# CLO    6573
# BEL    6574
# MAL    6570
# dtype: int64

# %%
for column in ['RPT', 'VAL', 'ROS', 'KIL', 'SHA', 'BIR', 'DUB', 'CLA', 'MUL', 'CLO', 'BEL', 'MAL']:
    print(f"Column: {column}")
    print("Non-null count:", data[column].notnull().sum())
    print("Unique values:", data[column].unique())
    print("Summary statistics:\n", data[column].describe())
    print("\n")
# Out:
# Column: RPT
# Non-null count: 6568
# Unique values: [15.04 14.71 18.5  10.58 13.33 13.21 13.5  10.96 12.58 13.37 19.75  9.92
#   9.04 12.04 16.42 17.75 19.83  4.92  9.59 14.33 16.54 25.04 13.62 24.37
#  22.04 17.67   nan 12.21 24.21 14.25 20.17 14.37 22.   24.5  18.05 24.54
#  17.41 20.5  16.79 16.   22.5  17.08  6.04 15.25 12.08 16.17 11.04  7.79
#  12.29 22.08  8.71 18.84 25.8  11.   12.92 12.67 11.25  4.88  6.46  7.54
#  11.96 10.63 14.79 11.21 12.12 11.12 15.71 16.88 11.42 13.75  9.54  6.34
#   6.38  6.29  9.67 15.    5.88  8.46 18.25  8.96  8.38  7.62 15.29 13.92
#  18.12  4.5   8.21 10.34  5.75 10.5  15.5   5.17  4.71  4.   10.83 16.71
#  21.09 15.34  8.17 14.04 16.29  4.08  5.58  9.62 11.67 15.87 19.04  9.87
#  23.   18.16 12.79  4.79  3.54  7.    9.25 10.    5.    6.21  6.83  6.25
#   4.96  5.54  7.67 11.79 10.92  9.96 15.92 11.29  7.5   8.5  11.58  8.33
#  11.92 12.17  9.71 14.42  8.29  6.13 13.88  8.92  8.54  8.83  5.71  6.42
# ...

# %%
data['date_string'] = pd.to_datetime(data['date_string'])
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15044\2904855273.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   data['date_string'] = pd.to_datetime(data['date_string'])

# %%
start_date = '1961-01-02'
end_date = pd.to_datetime(start_date) + pd.DateOffset(weeks=52)
weekly_data = data[(data['date_string'] >= start_date) & (data['date_string'] < end_date)]
weekly_data.set_index('date_string', inplace=True)

# %%
weekly_stats = weekly_data['BEL'].resample('W').agg(['min', 'max', 'mean', 'std'])
weekly_stats.reset_index(inplace=True)
print(weekly_stats)
# Out:
# Empty DataFrame
# Columns: [date_string, min, max, mean, std]
# Index: []
